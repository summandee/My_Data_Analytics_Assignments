# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df = pd.read_csv('compensation data.csv')
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df.shape
# Out:
# (25973, 6)

# %%
df.shape[0]
# Out:
# 25973

# %%
df.shape[1]
# Out:
# 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   experience_coding  25973 non-null  float64
#  1   python_user        25973 non-null  bool
#  2   r_user             25973 non-null  bool
#  3   sql_user           25973 non-null  bool
#  4   most_used          16835 non-null  object
#  5   compensation       25973 non-null  int64
# dtypes: bool(3), float64(1), int64(1), object(1)
# memory usage: 685.0+ KB

# %%
df.dtypes
# Out:
# experience_coding    float64
# python_user             bool
# r_user                  bool
# sql_user                bool
# most_used             object
# compensation           int64
# dtype: object

# %%
df.head()
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288

# %%
df.head(10)
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 0                6.1         True   False      True  Scikit-learn
# 1               12.3         True    True      True  Scikit-learn
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
# 6                1.8        False   False     False           NaN
# 7                6.1         True   False     False    TensorFlow
# 8                4.5         True   False      True  Scikit-learn
# 9                1.1         True   False      True    TensorFlow
#
#    compensation
# 0        124267
# 1        236889
# 2         74321
# 3         62593
# 4         36288
# 5         61302
# 6         68984
# 7         18858
# 8         55418
# 9           614

# %%
df.tail()
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 25968         15800
# 25969         62456
# 25970           923
# 25971         60609
# 25972           493

# %%
df.tail(15)
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 25958                1.3         True    True     False         Keras
# 25959                1.6         True   False      True    TensorFlow
# 25960               17.8         True   False      True       PyTorch
# 25961                3.7         True   False      True       PyTorch
# 25962                1.1         True   False     False    TensorFlow
# 25963               25.4         True   False     False       PyTorch
# 25964                5.9         True   False     False    TensorFlow
# 25965                2.0         True   False      True         Keras
# 25966                1.9         True   False     False  Scikit-learn
# 25967                6.1         True   False      True  Scikit-learn
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# ...

# %% [markdown]
# loc (Label-based indexing) Syntax: df.loc[row_label, column_label]

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df.loc[2]
# Out:
# experience_coding      2.2
# python_user           True
# r_user               False
# sql_user             False
# most_used              NaN
# compensation         74321
# Name: 2, dtype: object

# %%
df.loc[2,'compensation']
# Out:
# 74321

# %% [markdown]
# iloc (Integer-based indexing) Syntax: df.iloc[row_index, column_index]

# %%
df.iloc[2]
# Out:
# experience_coding      2.2
# python_user           True
# r_user               False
# sql_user             False
# most_used              NaN
# compensation         74321
# Name: 2, dtype: object

# %%
df.iloc[2,5]
# Out:
# 74321

# %%
# not allow
df.loc[2,5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\fujitsu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 2
#       1 # not allow
# ----> 2 df.loc[2,5]
#
# ...

# %%
df.loc[2:10]
# Out:
#     experience_coding  python_user  r_user  sql_user     most_used  \
# 2                 2.2         True   False     False           NaN
# 3                 2.7        False   False      True           NaN
# 4                 1.2         True   False     False  Scikit-learn
# 5                 1.0         True   False     False       PyTorch
# 6                 1.8        False   False     False           NaN
# 7                 6.1         True   False     False    TensorFlow
# 8                 4.5         True   False      True  Scikit-learn
# 9                 1.1         True   False      True    TensorFlow
# 10                2.7         True    True      True           NaN
#
#     compensation
# 2          74321
# 3          62593
# 4          36288
# 5          61302
# 6          68984
# 7          18858
# 8          55418
# 9            614
# 10         70564

# %%
df.iloc[2:10]
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
# 6                1.8        False   False     False           NaN
# 7                6.1         True   False     False    TensorFlow
# 8                4.5         True   False      True  Scikit-learn
# 9                1.1         True   False      True    TensorFlow
#
#    compensation
# 2         74321
# 3         62593
# 4         36288
# 5         61302
# 6         68984
# 7         18858
# 8         55418
# 9           614

# %%
df.iloc[2:10,:7]
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
# 6                1.8        False   False     False           NaN
# 7                6.1         True   False     False    TensorFlow
# 8                4.5         True   False      True  Scikit-learn
# 9                1.1         True   False      True    TensorFlow
#
#    compensation
# 2         74321
# 3         62593
# 4         36288
# 5         61302
# 6         68984
# 7         18858
# 8         55418
# 9           614

# %%
df.loc[2:9]
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
# 6                1.8        False   False     False           NaN
# 7                6.1         True   False     False    TensorFlow
# 8                4.5         True   False      True  Scikit-learn
# 9                1.1         True   False      True    TensorFlow
#
#    compensation
# 2         74321
# 3         62593
# 4         36288
# 5         61302
# 6         68984
# 7         18858
# 8         55418
# 9           614

# %%
df.loc[2:9,:'compensation']
# Out:
#    experience_coding  python_user  r_user  sql_user     most_used  \
# 2                2.2         True   False     False           NaN
# 3                2.7        False   False      True           NaN
# 4                1.2         True   False     False  Scikit-learn
# 5                1.0         True   False     False       PyTorch
# 6                1.8        False   False     False           NaN
# 7                6.1         True   False     False    TensorFlow
# 8                4.5         True   False      True  Scikit-learn
# 9                1.1         True   False      True    TensorFlow
#
#    compensation
# 2         74321
# 3         62593
# 4         36288
# 5         61302
# 6         68984
# 7         18858
# 8         55418
# 9           614

# %%
df1 = pd.read_csv('compensation data.csv',index_col=1)
df1
# Out:
#              experience_coding  r_user  sql_user     most_used  compensation
# python_user
# True                       6.1   False      True  Scikit-learn        124267
# True                      12.3    True      True  Scikit-learn        236889
# True                       2.2   False     False           NaN         74321
# False                      2.7   False      True           NaN         62593
# True                       1.2   False     False  Scikit-learn         36288
# ...                        ...     ...       ...           ...           ...
# True                       1.9   False      True  Scikit-learn         15800
# True                       1.4   False     False       PyTorch         62456
# False                      0.0   False     False           NaN           923
# True                       9.4   False      True  Scikit-learn         60609
# False                      0.0   False     False           NaN           493
#
# [25973 rows x 5 columns]

# %%
df1.loc['most_used']

# %%
df1.loc['Consumer',:'Quantity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\fujitsu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:876, in pandas._libs.index.BoolEngine._check_type()
#
# KeyError: 'Consumer'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df1.loc['Consumer',:'Quantity']
#
# ...

# %%
df.iloc[[2,10,3,9]]
# Out:
#     experience_coding  python_user  r_user  sql_user   most_used  compensation
# 2                 2.2         True   False     False         NaN         74321
# 10                2.7         True    True      True         NaN         70564
# 3                 2.7        False   False      True         NaN         62593
# 9                 1.1         True   False      True  TensorFlow           614

# %%
df.loc[[2,9,11],['r_user','sql_user']]
# Out:
#     r_user  sql_user
# 2    False     False
# 9    False      True
# 11    True     False

# %%
df.iloc[[2,10],[1,5]]
# Out:
#     python_user  compensation
# 2          True         74321
# 10         True         70564

# %%
df
# Out:
#        experience_coding  python_user  r_user  sql_user     most_used  \
# 0                    6.1         True   False      True  Scikit-learn
# 1                   12.3         True    True      True  Scikit-learn
# 2                    2.2         True   False     False           NaN
# 3                    2.7        False   False      True           NaN
# 4                    1.2         True   False     False  Scikit-learn
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True  Scikit-learn
# 25969                1.4         True   False     False       PyTorch
# 25970                0.0        False   False     False           NaN
# 25971                9.4         True   False      True  Scikit-learn
# 25972                0.0        False   False     False           NaN
#
#        compensation
# 0            124267
# 1            236889
# 2             74321
# 3             62593
# ...

# %%
df[['python_user','sql_user','most_used']]
# Out:
#        python_user  sql_user     most_used
# 0             True      True  Scikit-learn
# 1             True      True  Scikit-learn
# 2             True     False           NaN
# 3            False      True           NaN
# 4             True     False  Scikit-learn
# ...            ...       ...           ...
# 25968         True      True  Scikit-learn
# 25969         True     False       PyTorch
# 25970        False     False           NaN
# 25971         True      True  Scikit-learn
# 25972        False     False           NaN
#
# [25973 rows x 3 columns]

# %%
df[['python_user','sql_user','most_used']].head()
# Out:
#    python_user  sql_user     most_used
# 0         True      True  Scikit-learn
# 1         True      True  Scikit-learn
# 2         True     False           NaN
# 3        False      True           NaN
# 4         True     False  Scikit-learn

# %%
df.drop('most_used')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df.drop('most_used')
#
# File c:\Users\fujitsu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
# ...

# %%
df.drop('most_used',axis = 1)
# Out:
#        experience_coding  python_user  r_user  sql_user  compensation
# 0                    6.1         True   False      True        124267
# 1                   12.3         True    True      True        236889
# 2                    2.2         True   False     False         74321
# 3                    2.7        False   False      True         62593
# 4                    1.2         True   False     False         36288
# ...                  ...          ...     ...       ...           ...
# 25968                1.9         True   False      True         15800
# 25969                1.4         True   False     False         62456
# 25970                0.0        False   False     False           923
# 25971                9.4         True   False      True         60609
# 25972                0.0        False   False     False           493
#
# [25973 rows x 5 columns]

# %%
df
# Out:
#        experience_coding  r_user  sql_user     most_used  compensation
# 0                    6.1   False      True  Scikit-learn        124267
# 1                   12.3    True      True  Scikit-learn        236889
# 2                    2.2   False     False           NaN         74321
# 3                    2.7   False      True           NaN         62593
# 4                    1.2   False     False  Scikit-learn         36288
# ...                  ...     ...       ...           ...           ...
# 25968                1.9   False      True  Scikit-learn         15800
# 25969                1.4   False     False       PyTorch         62456
# 25970                0.0   False     False           NaN           923
# 25971                9.4   False      True  Scikit-learn         60609
# 25972                0.0   False     False           NaN           493
#
# [25973 rows x 5 columns]

# %%
df
# Out:
#        experience_coding  r_user  sql_user     most_used  compensation
# 0                    6.1   False      True  Scikit-learn        124267
# 1                   12.3    True      True  Scikit-learn        236889
# 2                    2.2   False     False           NaN         74321
# 3                    2.7   False      True           NaN         62593
# 4                    1.2   False     False  Scikit-learn         36288
# ...                  ...     ...       ...           ...           ...
# 25968                1.9   False      True  Scikit-learn         15800
# 25969                1.4   False     False       PyTorch         62456
# 25970                0.0   False     False           NaN           923
# 25971                9.4   False      True  Scikit-learn         60609
# 25972                0.0   False     False           NaN           493
#
# [25973 rows x 5 columns]

# %%
df
# Out:
#        experience_coding  r_user  sql_user     most_used  compensation
# 0                    6.1   False      True  Scikit-learn        124267
# 1                   12.3    True      True  Scikit-learn        236889
# 2                    2.2   False     False           NaN         74321
# 3                    2.7   False      True           NaN         62593
# 4                    1.2   False     False  Scikit-learn         36288
# ...                  ...     ...       ...           ...           ...
# 25967                6.1   False      True  Scikit-learn         80090
# 25968                1.9   False      True  Scikit-learn         15800
# 25969                1.4   False     False       PyTorch         62456
# 25970                0.0   False     False           NaN           923
# 25971                9.4   False      True  Scikit-learn         60609
#
# [25972 rows x 5 columns]

# %%
df.drop(25971,inplace = True)

# %%
df
# Out:
#        experience_coding  r_user  sql_user     most_used  compensation
# 0                    6.1   False      True  Scikit-learn        124267
# 1                   12.3    True      True  Scikit-learn        236889
# 2                    2.2   False     False           NaN         74321
# 3                    2.7   False      True           NaN         62593
# 4                    1.2   False     False  Scikit-learn         36288
# ...                  ...     ...       ...           ...           ...
# 25966                1.9   False     False  Scikit-learn          3932
# 25967                6.1   False      True  Scikit-learn         80090
# 25968                1.9   False      True  Scikit-learn         15800
# 25969                1.4   False     False       PyTorch         62456
# 25970                0.0   False     False           NaN           923
#
# [25971 rows x 5 columns]

# %%
df2 = pd.read_csv('compensation data.csv',header=None)
df2
# Out:
#                        0            1       2         3             4  \
# 0      experience_coding  python_user  r_user  sql_user     most_used
# 1                    6.1         TRUE   FALSE      TRUE  Scikit-learn
# 2                   12.3         TRUE    TRUE      TRUE  Scikit-learn
# 3                    2.2         TRUE   FALSE     FALSE           NaN
# 4                    2.7        FALSE   FALSE      TRUE           NaN
# ...                  ...          ...     ...       ...           ...
# 25969                1.9         TRUE   FALSE      TRUE  Scikit-learn
# 25970                1.4         TRUE   FALSE     FALSE       PyTorch
# 25971                  0        FALSE   FALSE     FALSE           NaN
# 25972                9.4         TRUE   FALSE      TRUE  Scikit-learn
# 25973                  0        FALSE   FALSE     FALSE           NaN
#
#                   5
# 0      compensation
# 1            124267
# 2            236889
# 3             74321
# ...

# %%
df3 = pd.read_csv('compensation data.csv',header=1)
df3
# Out:
#         6.1   TRUE  FALSE  TRUE.1  Scikit-learn  124267
# 0      12.3   True   True    True  Scikit-learn  236889
# 1       2.2   True  False   False           NaN   74321
# 2       2.7  False  False    True           NaN   62593
# 3       1.2   True  False   False  Scikit-learn   36288
# 4       1.0   True  False   False       PyTorch   61302
# ...     ...    ...    ...     ...           ...     ...
# 25967   1.9   True  False    True  Scikit-learn   15800
# 25968   1.4   True  False   False       PyTorch   62456
# 25969   0.0  False  False   False           NaN     923
# 25970   9.4   True  False    True  Scikit-learn   60609
# 25971   0.0  False  False   False           NaN     493
#
# [25972 rows x 6 columns]
